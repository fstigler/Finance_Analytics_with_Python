# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
yf.Ticker('INTC').info
# Out:
# {'zip': '95054-1549',
#  'sector': 'Technology',
#  'fullTimeEmployees': 117200,
#  'longBusinessSummary': 'Intel Corporation designs, manufactures, and sells essential technologies for the cloud, smart, and connected devices for retail, industrial, and consumer uses worldwide. The company operates through DCG, IOTG, Mobileye, NSG, PSG, CCG, and All Other segments. It offers platform products, such as central processing units and chipsets, and system-on-chip and multichip packages; and non-platform or adjacent products comprising accelerators, boards and systems, connectivity products, and memory and storage products. The company also provides Internet of Things products, including high-performance compute solutions for targeted verticals and embedded applications; and computer vision and machine learning-based sensing, data analysis, localization, mapping, and driving policy technology. It serves original equipment manufacturers, original design manufacturers, and cloud service providers. Intel Corporation has a strategic partnership with MILA to develop and apply advances in artificial intelligence methods for enhancing the search in the space of drugs. The company was founded in 1968 and is headquartered in Santa Clara, California.',
#  'city': 'Santa Clara',
#  'phone': '408 765 8080',
#  'state': 'CA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.intel.com',
#  'maxAge': 1,
#  'address1': '2200 Mission College Boulevard',
#  'industry': 'Semiconductors',
#  'ebitdaMargins': 0.44245,
#  'profitMargins': 0.2689,
#  'grossMargins': 0.56266,
#  'operatingCashflow': 34083999744,
#  'revenueGrowth': 0.047,
#  'operatingMargins': 0.29309,
#  'ebitda': 34721001472,
#  'targetLowPrice': 40,
#  'recommendationKey': 'hold',
#  'grossProfits': 43612000000,
#  'freeCashflow': 6137124864,
#  'targetMedianPrice': 55,
#  'currentPrice': 49.52,
#  'earningsGrowth': 0.637,
#  'currentRatio': 2.073,
#  'returnOnAssets': 0.09179,
#  'numberOfAnalystOpinions': 40,
#  'targetMeanPrice': 54.89,
#  'debtToEquity': 44.739,
#  'returnOnEquity': 0.25634,
#  'targetHighPrice': 80,
#  'totalCash': 34635001856,
#  'totalDebt': 40304001024,
#  'totalRevenue': 78474002432,
#  'totalCashPerShare': 8.516,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 19.302,
#  'quickRatio': 1.455,
#  'recommendationMean': 2.9,
#  'exchange': 'NMS',
#  'shortName': 'Intel Corporation',
#  'longName': 'Intel Corporation',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-18000000',
#  'quoteType': 'EQUITY',
#  'symbol': 'INTC',
#  'messageBoardId': 'finmb_21127',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 2.639,
#  'beta3Year': None,
#  'enterpriseToEbitda': 5.964,
#  '52WeekChange': 0.075119376,
#  'morningStarRiskRating': None,
#  'forwardEps': 3.7,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 4067000064,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 22.151,
#  'sharesShort': 72865700,
#  'sharesPercentSharesOut': 0.0179,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1608940800,
#  'heldPercentInstitutions': 0.64872,
#  'netIncomeToCommon': 21102000128,
#  'trailingEps': 5.158,
#  'lastDividendValue': 0.348,
#  'SandP52WeekChange': 0.31316328,
#  'priceToBook': 2.2355652,
#  'heldPercentInsiders': 0.00072999997,
#  'nextFiscalYearEnd': 1672012800,
#  'yield': None,
#  'mostRecentQuarter': 1632528000,
#  'shortRatio': 2.35,
#  'sharesShortPreviousMonthDate': 1632960000,
#  'floatShares': 4063217690,
#  'beta': 0.513766,
#  'enterpriseValue': 207066841088,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 965001600,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'lastDividendDate': 1635984000,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 0.596,
#  'priceToSalesTrailing12Months': 2.5664277,
#  'dateShortInterest': 1635465600,
#  'pegRatio': 2.98,
#  'ytdReturn': None,
#  'forwardPE': 13.383783,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0179,
#  'sharesShortPriorMonth': 58948195,
#  'impliedSharesOutstanding': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 49.68,
#  'regularMarketOpen': 49.6,
#  'twoHundredDayAverage': 56.63145,
#  'trailingAnnualDividendYield': 0.027636876,
#  'payoutRatio': 0.2665,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 49.73,
#  'navPrice': None,
#  'averageDailyVolume10Day': 26589950,
#  'regularMarketPreviousClose': 49.68,
#  'fiftyDayAverage': 52.3028,
#  'trailingAnnualDividendRate': 1.373,
#  'open': 49.6,
#  'toCurrency': None,
#  'averageVolume10days': 26589950,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': 1.39,
#  'exDividendDate': 1635984000,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 49.24,
#  'currency': 'USD',
#  'trailingPE': 9.60062,
#  'regularMarketVolume': 27607603,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 201397846016,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 25380673,
#  'dayLow': 49.24,
#  'ask': 49.51,
#  'askSize': 2200,
#  'volume': 27607603,
#  'fiftyTwoWeekHigh': 68.49,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 2.49,
#  'fiftyTwoWeekLow': 45.24,
#  'bid': 49.47,
#  'tradeable': False,
#  'dividendYield': 0.028099999,
#  'bidSize': 1000,
#  'dayHigh': 49.73,
#  'regularMarketPrice': 49.52,
#  'preMarketPrice': None,
#  'logo_url': 'https://logo.clearbit.com/intel.com'}

# %%
tickers = ['INTC', 'MSFT', 'IBM']

# %%
infos = []

for i in tickers: 
    infos.append(yf.Ticker(i).info)

# %%
fundamentals = ['dividendYield', 'marketCap', 'beta', 'forwardPE']

# %%
df = pd.DataFrame(infos)

# %%
df = df.set_index('symbol')

# %%
df[df.columns[df.columns.isin(fundamentals)]]
# Out:
#             beta  forwardPE      marketCap  dividendYield
# symbol
# INTC    0.513766  13.383783   201397846016         0.0281
# MSFT    0.862337  32.584045  2576062873600         0.0072
# IBM     1.101818  11.456071   104017936384         0.0565

# %%
plt.bar(df.index,df.dividendYield, color=('k','orange', 'cyan'))
plt.show()

# %%
df2 = pd.read_html('https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average')[1]

# %%
tickers = df2.Symbol.to_list()

# %%
tickers
# Out:
# ['MMM',
#  'AXP',
#  'AMGN',
#  'AAPL',
#  'BA',
#  'CAT',
#  'CVX',
#  'CSCO',
#  'KO',
#  'DIS',
#  'DOW',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'INTC',
#  'JNJ',
#  'JPM',
#  'MCD',
#  'MRK',
#  'MSFT',
#  'NKE',
#  'PG',
#  'CRM',
#  'TRV',
#  'UNH',
#  'VZ',
#  'V',
#  'WBA',
#  'WMT']

# %%
infos = []

for i in tickers:
    infos.append(yf.Ticker(i).info)

# %%
df2 = pd.DataFrame(infos)

# %%
df2 = df2.set_index('symbol')

# %%
df2
# Out:
#                zip                  sector  fullTimeEmployees  \
# symbol
# MMM     55144-1000             Industrials            95000.0
# AXP          10285      Financial Services            63700.0
# AMGN    91320-1799              Healthcare            24300.0
# AAPL         95014              Technology           154000.0
# BA      60606-1596             Industrials           141000.0
# CAT          60015             Industrials            97300.0
# CVX     94583-2324                  Energy            47736.0
# CSCO         95134              Technology            79500.0
# KO           30313      Consumer Defensive            80300.0
# DIS          91521  Communication Services                NaN
# DOW          48674         Basic Materials            35700.0
# GS           10282      Financial Services            43000.0
# HD           30339       Consumer Cyclical           500000.0
# HON          28202             Industrials           103000.0
# IBM          10504              Technology           345900.0
# INTC    95054-1549              Technology           117200.0
# JNJ          08933              Healthcare           134500.0
# JPM          10179      Financial Services           265790.0
# MCD          60607       Consumer Cyclical           200000.0
# MRK          07033              Healthcare            73000.0
# MSFT    98052-6399              Technology           181000.0
# NKE     97005-6453       Consumer Cyclical            73300.0
# PG           45202      Consumer Defensive           101000.0
# CRM          94105              Technology            59895.0
# TRV     10017-2630      Financial Services            29988.0
# UNH          55343              Healthcare           330000.0
# VZ           10036  Communication Services           129300.0
# V            94128      Financial Services            20500.0
# WBA          60015              Healthcare           223000.0
# WMT          72716      Consumer Defensive          2300000.0
#
#                                       longBusinessSummary           city  \
# symbol
# MMM     3M Company develops, manufactures, and markets...       St. Paul
# AXP     American Express Company, together with its su...       New York
# AMGN    Amgen Inc. discovers, develops, manufactures, ...  Thousand Oaks
# DIS       http://www.thewaltdisneycompany.com  ...  155.210
# DOW                        http://www.dow.com  ...   57.520
# GS                http://www.goldmansachs.com  ...  390.240
# HD                   http://www.homedepot.com  ...  410.100
# HON                  http://www.honeywell.com  ...  221.200
# IBM                        http://www.ibm.com  ...  116.560
# INTC                     http://www.intel.com  ...   49.730
# JNJ                        http://www.jnj.com  ...  163.190
# JPM              http://www.jpmorganchase.com  ...  162.110
# MCD            http://corporate.mcdonalds.com  ...  253.320
# MRK                      http://www.merck.com  ...   82.750
# MSFT                 http://www.microsoft.com  ...  345.100
# NKE                       http://www.nike.com  ...  177.200
# PG                  http://www.pginvestor.com  ...  148.230
# CRM                 http://www.salesforce.com  ...  306.990
# TRV                  http://www.travelers.com  ...  157.810
# UNH          http://www.unitedhealthgroup.com  ...  452.810
# VZ                     http://www.verizon.com  ...   51.645
# V                         http://usa.visa.com  ...  207.870
# WBA     http://www.walgreensbootsalliance.com  ...   47.970
# WMT              http://www.stock.walmart.com  ...  143.290
#
#        regularMarketPrice preMarketPrice  \
# symbol
# MMM                179.23           None
# AXP                173.54           None
# AMGN               206.08           None
# AAPL               160.55           None
# BA                 214.13           None
# CAT                200.44           None
# CVX                111.91           None
# CSCO                53.25           None
# KO                  55.13           None
# DIS                154.00           None
# DOW                 57.34           None
# GS                 387.39           None
# HD                 408.69           None
# HON                218.49           None
# IBM                116.05           None
# INTC                49.52           None
# JNJ                162.89           None
# JPM                160.92           None
# MCD                251.95           None
# MRK                 80.70           None
# MSFT               343.11           None
# NKE                174.88           None
# PG                 146.82           None
# CRM                302.99           None
# TRV                156.03           None
# UNH                449.47           None
# VZ                  51.24           None
# V                  203.33           None
# WBA                 47.82           None
# WMT                143.16           None
#
#                                                  logo_url           fax  \
# symbol
# MMM                      https://logo.clearbit.com/3m.com           NaN
# AXP         https://logo.clearbit.com/americanexpress.com           NaN
# AMGN                  https://logo.clearbit.com/amgen.com  805 447 1010
# AAPL                  https://logo.clearbit.com/apple.com           NaN
# BA                   https://logo.clearbit.com/boeing.com           NaN
# CAT             https://logo.clearbit.com/caterpillar.com           NaN
# CVX                 https://logo.clearbit.com/chevron.com           NaN
# CSCO                  https://logo.clearbit.com/cisco.com           NaN
# KO         https://logo.clearbit.com/coca-colacompany.com           NaN
# DIS     https://logo.clearbit.com/thewaltdisneycompany...           NaN
# DOW                     https://logo.clearbit.com/dow.com  989 832 1456
# GS             https://logo.clearbit.com/goldmansachs.com           NaN
# HD                https://logo.clearbit.com/homedepot.com           NaN
# HON               https://logo.clearbit.com/honeywell.com           NaN
# IBM                     https://logo.clearbit.com/ibm.com           NaN
# INTC                  https://logo.clearbit.com/intel.com           NaN
# JNJ                     https://logo.clearbit.com/jnj.com           NaN
# JPM           https://logo.clearbit.com/jpmorganchase.com           NaN
# MCD     https://logo.clearbit.com/corporate.mcdonalds.com           NaN
# MRK                   https://logo.clearbit.com/merck.com           NaN
# MSFT              https://logo.clearbit.com/microsoft.com           NaN
# NKE                    https://logo.clearbit.com/nike.com           NaN
# PG               https://logo.clearbit.com/pginvestor.com           NaN
# CRM              https://logo.clearbit.com/salesforce.com  415 901 7040
# TRV               https://logo.clearbit.com/travelers.com           NaN
# UNH       https://logo.clearbit.com/unitedhealthgroup.com           NaN
# VZ                  https://logo.clearbit.com/verizon.com           NaN
# V                  https://logo.clearbit.com/usa.visa.com           NaN
# WBA     https://logo.clearbit.com/walgreensbootsallian...           NaN
# WMT           https://logo.clearbit.com/stock.walmart.com           NaN
#
#                             address2  underlyingSymbol  \
# symbol
# MMM                              NaN               NaN
# AXP                              NaN               NaN
# AMGN                             NaN               NaN
# AAPL                             NaN               NaN
# BA                               NaN               NaN
# CAT                        Suite 100               NaN
# CVX                              NaN               NaN
# CSCO                             NaN               NaN
# KO                               NaN               NaN
# DIS                              NaN               NaN
# DOW                              NaN               NaN
# GS                        29th Floor               NaN
# HD                               NaN               NaN
# HON                              NaN               NaN
# IBM                              NaN               NaN
# INTC                             NaN               NaN
# JNJ                              NaN               NaN
# JPM                              NaN               NaN
# MCD                              NaN               NaN
# MRK                              NaN               NaN
# MSFT                             NaN               NaN
# NKE                              NaN               NaN
# PG                               NaN               NaN
# CRM     3rd Floor 415 Mission Street               NaN
# TRV                              NaN               NaN
# UNH              9900 Bren Road East               NaN
# VZ                               NaN               NaN
# V                                NaN               NaN
# WBA                              NaN               NaN
# WMT                              NaN               NaN
#
#         underlyingExchangeSymbol  headSymbol  \
# symbol
# MMM                          NaN         NaN
# AXP                          NaN         NaN
# AMGN                         NaN         NaN
# AAPL                         NaN         NaN
# BA                           NaN         NaN
# CAT                          NaN         NaN
# CVX                          NaN         NaN
# CSCO                         NaN         NaN
# KO                           NaN         NaN
# DIS                          NaN         NaN
# DOW                          NaN         NaN
# GS                           NaN         NaN
# HD                           NaN         NaN
# HON                          NaN         NaN
# IBM                          NaN         NaN
# INTC                         NaN         NaN
# JNJ                          NaN         NaN
# JPM                          NaN         NaN
# MCD                          NaN         NaN
# MRK                          NaN         NaN
# MSFT                         NaN         NaN
# NKE                          NaN         NaN
# PG                           NaN         NaN
# CRM                          NaN         NaN
# TRV                          NaN         NaN
# UNH                          NaN         NaN
# VZ                           NaN         NaN
# V                            NaN         NaN
# WBA                          NaN         NaN
# WMT                          NaN         NaN
#
#                                         uuid
# symbol
# MMM                                      NaN
# AXP                                      NaN
# AMGN                                     NaN
# AAPL                                     NaN
# BA                                       NaN
# CAT                                      NaN
# CVX                                      NaN
# CSCO                                     NaN
# KO                                       NaN
# DIS                                      NaN
# DOW                                      NaN
# GS                                       NaN
# HD                                       NaN
# HON                                      NaN
# IBM                                      NaN
# INTC                                     NaN
# JNJ                                      NaN
# JPM                                      NaN
# MCD                                      NaN
# MRK                                      NaN
# MSFT                                     NaN
# NKE                                      NaN
# PG                                       NaN
# CRM                                      NaN
# TRV     f9648b70-41f5-3bd8-a005-3a20a688b790
# UNH     33ae4437-560d-3a42-9aa4-234d48c993c5
# VZ      a708480c-0400-3ea0-b2d3-ca752db5c3b1
# V       5206560a-306a-3e08-9a43-7fd258eb57ce
# WBA     888fa4a2-1f3d-3718-83dd-229207680ca9
# WMT     902d429a-38af-3903-a1d7-3374c3560928
#
# [30 rows x 157 columns]

# %%
df2['dividendYield'].nlargest(5)
# Out:
# symbol
# IBM    0.0565
# DOW    0.0488
# CVX    0.0479
# VZ     0.0455
# WBA    0.0360
# Name: dividendYield, dtype: float64

# %%
plt.figure(figsize=(14,5))
plt.bar(df2['shortName'],df2['dividendYield'])
plt.xticks(rotation=90)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
