# %%
import pandas_datareader.data as reader
import pandas as pd
import datetime as dt
from dateutil.relativedelta import relativedelta
import yfinance as yf
import numpy as np

# %%
wiki = 'https://en.wikipedia.org/wiki/'

# %%
# Get ticker symbols for the stocks contained in S&P 500

tickers = pd.read_html(wiki+'Dow_Jones_Industrial_Average')[1].Symbol.to_list()
tickers
# Out:
# ['MMM',
#  'AXP',
#  'AMGN',
#  'AAPL',
#  'BA',
#  'CAT',
#  'CVX',
#  'CSCO',
#  'KO',
#  'DOW',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'INTC',
#  'JNJ',
#  'JPM',
#  'MCD',
#  'MRK',
#  'MSFT',
#  'NKE',
#  'PG',
#  'CRM',
#  'TRV',
#  'UNH',
#  'VZ',
#  'V',
#  'WBA',
#  'WMT',
#  'DIS']

# %%
# Get prices for the DJI components

start = dt.datetime(2018,1,31)
end = dt.datetime(2020,1,31)

df = reader.get_data_yahoo(tickers,start,end)['Adj Close']

# %%
df
# Out:
# Symbols            MMM         AXP        AMGN       AAPL          BA  \
# Date
# 2018-01-31  222.390884   94.101677  166.955017  40.033287  337.712067
# 2018-02-01  220.118118   94.669693  166.515350  40.116962  340.161255
# 2018-02-02  217.658981   91.526665  167.816498  38.376289  332.508759
# 2018-02-05  205.469635   87.105583  156.814804  37.417484  313.420349
# 2018-02-06  207.413895   89.159920  158.519806  38.981232  324.884827
# ...                ...         ...         ...        ...         ...
# 2020-01-27  165.451416  127.309425  212.209702  76.107002  314.727478
# 2020-01-28  155.983841  129.073288  214.008667  78.260017  314.687714
# 2020-01-29  152.611313  128.322922  216.207382  79.898186  320.115387
# 2020-01-30  153.091766  129.823669  215.255554  79.782394  321.387817
# 2020-01-31  149.464905  126.559067  205.642105  76.244949  316.387573
#
# Symbols            CAT         CVX       CSCO         KO        DOW  ...  \
# Date                                                                 ...
# 2018-01-31  147.910355  105.500854  37.099243  42.117508        NaN  ...
# 2018-02-01  147.419693  105.686020  37.242138  41.993607        NaN  ...
# 2018-02-02  143.103607   99.802895  36.554451  41.356392        NaN  ...
# 2018-02-05  137.279129   94.786667  34.634300  39.727989        NaN  ...
# 2018-02-06  142.122223   98.624565  35.875706  39.533276        NaN  ...
# ...                ...         ...        ...        ...        ...  ...
# 2020-01-27  129.969894  100.414772  44.913219  54.297291  42.954826  ...
# 2020-01-28  130.937012  101.078819  45.197056  53.853317  42.936619  ...
# 2020-01-29  130.017761  100.396584  44.515839  53.853317  45.221832  ...
# 2020-01-30  129.625153  101.333511  44.695602  55.600880  44.129299  ...
# 2020-01-31  125.775757   97.458458  43.494007  55.166344  41.944229  ...
#
# Symbols           NKE          PG         CRM         TRV         UNH  \
# Date
# 2018-01-31  65.745346   77.810410  113.910004  137.057419  223.617401
# 2018-02-01  65.196037   77.368805  112.739998  137.130554  222.144119
# 2018-02-02  64.781624   75.926880  110.779999  135.256424  218.989792
# 2018-02-05  62.054287   73.052017  107.650002  129.378113  207.789108
# 2018-02-06  62.854187   74.241615  109.570000  128.765564  212.662247
# ...               ...         ...         ...         ...         ...
# 2020-01-27  98.729797  120.361900  180.710007  128.012985  276.514038
# 2020-01-28  98.897247  120.687477  182.850006  128.644745  278.246552
# 2020-01-29  98.335831  119.758606  181.770004  127.572639  275.355713
# 2020-01-30  96.710693  120.610863  185.669998  128.462875  273.486969
# 2020-01-31  94.849174  119.337250  182.309998  125.993195  265.184418
#
# Symbols            VZ           V        WBA         WMT         DIS
# Date
# 2018-01-31  45.907909  121.126717  66.361534   99.212181  105.682106
# 2018-02-01  46.103195  122.579491  67.066940   98.207016  107.452065
# 2018-02-02  44.982452  117.889648  64.862511   97.239113  105.711281
# 2018-02-05  42.876816  113.365555  62.102612   93.153343  101.821266
# 2018-02-06  43.157005  116.973137  63.301819   93.907211  103.250854
# ...               ...         ...        ...         ...         ...
# 2020-01-27  55.482132  199.232300  48.646282  112.625473  135.899994
# 2020-01-28  56.213745  200.378174  49.158543  113.344810  138.369995
# 2020-01-29  55.130219  202.363663  48.692852  112.654633  136.059998
# 2020-01-30  54.972782  205.672836  48.385490  113.325371  137.809998
# 2020-01-31  55.046867  196.545441  47.360966  111.293716  138.309998
#
# [504 rows x 30 columns]

# %%
# Calculate monthly retunrs by cumulating daily returns

mtl_ret = df.pct_change().resample('M').agg(lambda x:(x+1).prod() -1)
mtl_ret
# Out:
# Symbols          MMM       AXP      AMGN      AAPL        BA       CAT  \
# Date
# 2018-01-31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2018-02-28 -0.054297 -0.019014 -0.004788  0.068185  0.027169 -0.050068
# 2018-03-31 -0.067895 -0.043380 -0.072319 -0.058051 -0.094779 -0.046886
# 2018-04-30 -0.114477  0.062615  0.023463 -0.015019  0.017323 -0.015559
# 2018-05-31  0.021549 -0.004557  0.037404  0.135124  0.061029  0.052300
# 2018-06-30 -0.002586 -0.003052  0.027670 -0.009418 -0.047279 -0.106905
# 2018-07-31  0.079301  0.019156  0.064792  0.027983  0.061965  0.066423
# 2018-08-31  0.000065  0.064912  0.023505  0.200422 -0.033164 -0.034423
# 2018-09-30 -0.000996  0.004812  0.037435 -0.008303  0.084921  0.098236
# 2018-10-31 -0.097053 -0.031827 -0.069950 -0.030478 -0.045819 -0.199336
# 2018-11-30  0.100283  0.092865  0.087734 -0.181198 -0.018313  0.118282
# 2018-12-31 -0.083590 -0.150975 -0.065210 -0.116698 -0.069962 -0.063389
# 2019-01-31  0.051223  0.081833 -0.038835  0.055154  0.195721  0.054668
# 2019-02-28  0.042555  0.049075  0.023728  0.044777  0.146648  0.031391
# 2019-03-31  0.001881  0.014479 -0.000526  0.097026 -0.133057 -0.013470
# 2019-04-30 -0.087930  0.076349 -0.056111  0.056436 -0.009779  0.035243
# 2019-05-31 -0.149824 -0.021496 -0.062374 -0.124213 -0.090332 -0.140654
# 2019-06-30  0.085070  0.076105  0.105459  0.130519  0.065572  0.137551
# 2019-07-31  0.007961  0.010685  0.012481  0.076395 -0.062718 -0.026465
# 2019-08-31 -0.065935 -0.032162  0.126048 -0.016461  0.073808 -0.096225
# 2019-09-30  0.016572 -0.017363 -0.072428  0.072962  0.044989  0.061429
# 2019-10-31  0.003589 -0.004662  0.102010  0.110684 -0.106605  0.099542
# 2019-11-30  0.037880  0.024216  0.107994  0.077554  0.083572  0.050290
# 2019-12-31  0.039171  0.036380  0.027054  0.098784 -0.110383  0.020383
# 2020-01-31 -0.100669  0.046832 -0.103787  0.054010 -0.022993 -0.104338
#
# Symbols          CVX      CSCO        KO       DOW  ...       NKE        PG  \
# Date                                                ...
# 2018-01-31  0.000000  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 
# 2018-11-30  0.040221  0.041876  0.080004  0.056227  0.029847  0.067159
# 2018-12-31 -0.040558 -0.075786 -0.114586 -0.067662 -0.068944 -0.192984
# 2019-01-31  0.109513  0.048351  0.084618 -0.010412  0.023268  0.057515
# 2019-02-28  0.076857  0.058706 -0.103553  0.033781  0.099019 -0.008786
# 2019-03-31 -0.032264  0.038056  0.024704  0.038827  0.054483 -0.111252
# 2019-04-30  0.044074  0.048046 -0.057389 -0.022844  0.052756 -0.153311
# 2019-05-31 -0.084306  0.012661  0.037456 -0.049659 -0.017344 -0.071178
# 2019-06-30  0.002113  0.032819  0.013609  0.051150  0.075746  0.108026
# 2019-07-31  0.018256 -0.019395  0.020491 -0.022374  0.025641 -0.003292
# 2019-08-31  0.010162  0.002319 -0.060279  0.052289  0.017308 -0.051960
# 2019-09-30 -0.048888  0.017229 -0.066902  0.037827 -0.048722  0.080485
# 2019-10-31  0.054231 -0.118569  0.162801  0.012247  0.039823 -0.009582
# 2019-11-30  0.040897  0.043186  0.107519 -0.003804  0.033317  0.096093
# 2019-12-31 -0.001535  0.007771  0.054454  0.019256  0.018373 -0.010738
# 2020-01-31  0.120942 -0.038919 -0.073236 -0.021847  0.058914 -0.137551
#
# Symbols          WMT       DIS
# Date
# 2018-01-31  0.000000  0.000000
# 2018-02-28 -0.155628 -0.050704
# 2018-03-31 -0.005661 -0.026367
# 2018-04-30 -0.005732 -0.001095
# 2018-05-31 -0.061044 -0.008572
# 2018-06-30  0.037679  0.053684
# 2018-07-31  0.041798  0.092194
# 2018-08-31  0.080542 -0.013561
# 2018-09-30 -0.020342  0.043921
# 2018-10-31  0.067831 -0.018043
# 2018-11-30 -0.026227  0.005748
# 2018-12-31 -0.040877 -0.043203
# 2019-01-31  0.028771  0.017054
# 2019-02-28  0.032975  0.011837
# 2019-03-31 -0.009448 -0.016040
# 2019-04-30  0.054445  0.233631
# 2019-05-31 -0.008374 -0.035993
# 2019-06-30  0.089215  0.057558
# 2019-07-31 -0.000996  0.030476
# 2019-08-31  0.040247 -0.040207
# 2019-09-30  0.038684 -0.050561
# 2019-10-31 -0.011965 -0.003069
# 2019-11-30  0.015606  0.166718
# 2019-12-31  0.002377 -0.040134
# 2020-01-31 -0.036604 -0.043698
#
# [25 rows x 30 columns]

# %%
# Calculate returns over the past 11 months

past_11 = (mtl_ret+1).rolling(11).apply(np.prod)-1
past_11
# Out:
# Symbols          MMM       AXP      AMGN      AAPL        BA       CAT  \
# Date
# 2018-01-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-02-28       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-03-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-04-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-05-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-06-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-07-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-08-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-09-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-10-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-11-30 -0.147962  0.141894  0.152214  0.082608 -0.002270 -0.151840
# 2018-12-31 -0.219184 -0.030504  0.077078 -0.043731 -0.072073 -0.205604
# 2019-01-31 -0.132062  0.069162  0.040230 -0.055397  0.080194 -0.118018
# 2019-02-28 -0.029215  0.172494  0.147929  0.047721  0.368287 -0.045582
# 2019-03-31  0.098346  0.119381  0.121023  0.166903  0.166026 -0.043557
# 2019-04-30 -0.019363  0.210360  0.019969  0.086012  0.088212 -0.059060
# 2019-07-31  0.011920  0.140484 -0.058633  0.060289  0.217956 -0.189251
# 2019-08-31 -0.018613  0.153049 -0.110332  0.136210  0.212620 -0.277136
# 2019-09-30  0.081609  0.215846 -0.154956  0.090680  0.255963 -0.286222
# 2019-10-31  0.096175  0.028610 -0.090172  0.045265  0.268130 -0.337551
# 2019-11-30  0.189239  0.161022  0.138058  0.116858  0.407412 -0.100258
# 2019-12-31  0.070211  0.116080  0.106408  0.150342  0.400679 -0.158329
# 2020-01-31  0.114024  0.013164  0.143826  0.088441  0.349567 -0.267667
#
# Symbols          WMT       DIS
# Date
# 2018-01-31       NaN       NaN
# 2018-02-28       NaN       NaN
# 2018-03-31       NaN       NaN
# 2018-04-30       NaN       NaN
# 2018-05-31       NaN       NaN
# 2018-06-30       NaN       NaN
# 2018-07-31       NaN       NaN
# 2018-08-31       NaN       NaN
# 2018-09-30       NaN       NaN
# 2018-10-31       NaN       NaN
# 2018-11-30 -0.067306  0.071302
# 2018-12-31 -0.105432  0.025019
# 2019-01-31  0.089929  0.098181
# 2019-02-28  0.132280  0.141272
# 2019-03-31  0.128049  0.124197
# 2019-04-30  0.266796  0.398834
# 2019-05-31  0.210576  0.279781
# 2019-06-30  0.265675  0.239197
# 2019-07-31  0.170167  0.294517
# 2019-08-31  0.242539  0.190194
# 2019-09-30  0.208623  0.150781
# 2019-10-31  0.226324  0.140692
# 2019-11-30  0.298543  0.390960
# 2019-12-31  0.265228  0.312747
# 2020-01-31  0.180005  0.240698
#
# [25 rows x 30 columns]

# %%
formation = dt.datetime(2019,12,31)

end_measurement = formation - relativedelta(months=1)

# %%
formation
# Out:
# datetime.datetime(2019, 12, 31, 0, 0)

# %%
end_measurement
# Out:
# datetime.datetime(2019, 11, 30, 0, 0)

# %%
ret_12 = past_11.loc[end_measurement]

# %%
ret_12 = ret_12.reset_index()

# %%
ret_12
# Out:
#    Symbols  2019-11-30 00:00:00
# 0      MMM            -0.078985
# 1      AXP             0.278656
# 2     AMGN             0.242400
# 3     AAPL             0.719700
# 4       BA             0.161603
# 5      CAT             0.171263
# 6      CVX             0.120405
# 7     CSCO             0.075240
# 8       KO             0.163507
# 9      DOW             0.119667
# 10      GS             0.352369
# 11      HD             0.309954
# 12     HON             0.378922
# 13     IBM             0.239541
# 14    INTC             0.267808
# 15     JNJ             0.095434
# 16     JPM             0.391864
# 17     MCD             0.121662
# 18     MRK             0.164049
# 19    MSFT             0.512438
# 20     NKE             0.274348
# 21      PG             0.365239
# 22     CRM             0.189239
# 23     TRV             0.161022
# 24     UNH             0.138058
# 25      VZ             0.116858
# 26       V             0.407412
# 27     WBA            -0.100258
# 28     WMT             0.298543
# 29     DIS             0.390960

# %%
ret_12['quintile'] = pd.qcut(ret_12.iloc[:,1],5, labels=False)

# %%
ret_12
# Out:
#    Symbols  2019-11-30 00:00:00  quintile
# 0      MMM            -0.078985         0
# 1      AXP             0.278656         3
# 2     AMGN             0.242400         2
# 3     AAPL             0.719700         4
# 4       BA             0.161603         1
# 5      CAT             0.171263         2
# 6      CVX             0.120405         1
# 7     CSCO             0.075240         0
# 8       KO             0.163507         1
# 9      DOW             0.119667         0
# 10      GS             0.352369         3
# 11      HD             0.309954         3
# 12     HON             0.378922         4
# 13     IBM             0.239541         2
# 14    INTC             0.267808         2
# 15     JNJ             0.095434         0
# 16     JPM             0.391864         4
# 17     MCD             0.121662         1
# 18     MRK             0.164049         2
# 19    MSFT             0.512438         4
# 20     NKE             0.274348         3
# 21      PG             0.365239         3
# 22     CRM             0.189239         2
# 23     TRV             0.161022         1
# 24     UNH             0.138058         1
# 25      VZ             0.116858         0
# 26       V             0.407412         4
# 27     WBA            -0.100258         0
# 28     WMT             0.298543         3
# 29     DIS             0.390960         4

# %%
winners = ret_12[ret_12.quintile == 4]
losers = ret_12[ret_12.quintile == 0]

# %%
winners
# Out:
#    Symbols  2019-11-30 00:00:00  quintile
# 3     AAPL             0.719700         4
# 12     HON             0.378922         4
# 16     JPM             0.391864         4
# 19    MSFT             0.512438         4
# 26       V             0.407412         4
# 29     DIS             0.390960         4

# %%
losers
# Out:
#    Symbols  2019-11-30 00:00:00  quintile
# 0      MMM            -0.078985         0
# 7     CSCO             0.075240         0
# 9      DOW             0.119667         0
# 15     JNJ             0.095434         0
# 25      VZ             0.116858         0
# 27     WBA            -0.100258         0

# %%
winnerret = mtl_ret.loc[formation + relativedelta(months=1),df.columns.isin(winners.Symbols)]
loserret = mtl_ret.loc[formation + relativedelta(months=1),df.columns.isin(losers.Symbols)]

# %%
winnerret
# Out:
# Symbols
# AAPL    0.054010
# HON    -0.021356
# JPM    -0.044407
# MSFT    0.079455
# V       0.058914
# DIS    -0.043698
# Name: 2020-01-31 00:00:00, dtype: float64

# %%
loserret
# Out:
# Symbols
# MMM    -0.100669
# CSCO   -0.034447
# DOW    -0.158231
# JNJ     0.020566
# VZ     -0.021847
# WBA    -0.137551
# Name: 2020-01-31 00:00:00, dtype: float64

# %%
Momentumprofit = winnerret.mean() - loserret.mean()
Momentumprofit
# Out:
# 0.08584945906901634

# %%
DJI = reader.get_data_yahoo('^DJI',start,end)['Adj Close'].pct_change().resample('M').agg(lambda x: (x+1).prod()-1)

# %%
DJI
# Out:
# Date
# 2018-01-31    0.000000
# 2018-02-28   -0.042838
# 2018-03-31   -0.037000
# 2018-04-30    0.002491
# 2018-05-31    0.010458
# 2018-06-30   -0.005915
# 2018-07-31    0.047125
# 2018-08-31    0.021626
# 2018-09-30    0.019006
# 2018-10-31   -0.050742
# 2018-11-30    0.016830
# 2018-12-31   -0.086575
# 2019-01-31    0.071684
# 2019-02-28    0.036654
# 2019-03-31    0.000489
# 2019-04-30    0.025618
# 2019-05-31   -0.066855
# 2019-06-30    0.071929
# 2019-07-31    0.009936
# 2019-08-31   -0.017160
# 2019-09-30    0.019450
# 2019-10-31    0.004807
# 2019-11-30    0.037165
# 2019-12-31    0.017362
# 2020-01-31   -0.009896
# Freq: M, Name: Adj Close, dtype: float64
